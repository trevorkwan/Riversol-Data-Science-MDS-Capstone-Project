# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv("../../data/processed/cleaned_df.csv")

# %%
df
# Out:
#           customer_id  accepts_marketing  ordered_month  \
# 0           510336833               True              4
# 1           544818881              False              6
# 2           577330433              False              5
# 3           584222401              False              5
# 4           593077569              False              5
# ...               ...                ...            ...
# 604074  2986770989103               True              4
# 604075  2986771546159               True              4
# 604076  2986771644463              False              4
# 604077  2986772168751               True              4
# 604078  2986772889647               True              4
#
#                          location   gender  free_shipping product_type  \
# 0                 ONTARIO, CANADA  unknown           True   Anti-Aging
# 1        BRITISH COLUMBIA, CANADA  unknown          False        Other
# 2           OREGON, UNITED STATES   female          False        Other
# 3       NEW JERSEY, UNITED STATES  unknown          False        Other
# 4                 ONTARIO, CANADA  unknown          False        Other
# ...                           ...      ...            ...          ...
# 604074            ONTARIO, CANADA   female           True   Anti-Aging
# 604075            ONTARIO, CANADA   female           True   Anti-Aging
# 604076        NOVA SCOTIA, CANADA   female           True   Anti-Aging
# 604077            ONTARIO, CANADA   female           True   Anti-Aging
# 604078            ONTARIO, CANADA  unknown           True   Anti-Aging
#
#              skin_type                fv_site              order_url    buy
# 0        Normal to Dry                   auto                   auto  False
# 1       Normal to Oily                    NaN                unknown   True
# 2        Normal to Dry                    NaN                unknown   True
# 3       Normal to Oily                    NaN                unknown  False
# 4        Normal to Dry                    NaN                unknown  False
# ...                ...                    ...                    ...    ...
# 604074     Combination         Instagram_Feed         Instagram_Feed  False
# 604075     Combination   Facebook_Mobile_Feed   Facebook_Mobile_Feed  False
# 604076     Combination                    NaN                unknown  False
# 604077     Combination  Facebook_Desktop_Feed  Facebook_Desktop_Feed  False
# 604078     Combination   Facebook_Mobile_Feed   Facebook_Mobile_Feed  False
#
# [604079 rows x 11 columns]

# %%
# split data again
X = df.drop(columns='buy')
y = df[['buy']]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=123)

# %%
train_df = pd.concat([X_train, y_train], axis = 1)

# %%
skin_type_counts = plt.figure(figsize = (10, 6))
skin_type_counts = sns.countplot(data = train_df, x = 'skin_type', hue = 'buy')
skin_type_counts.set(xlabel = 'Skin Type', ylabel = 'Count', title = "Sample-Taker to Purchaser Based on Skin Type")
skin_type_counts.legend(title = "Purchased")
    
skin_type_counts.figure.savefig(os.path.join(file_path, 'skin_type_counts.png'))

# %%
product_type_counts = plt.figure(figsize = (10, 6))
product_type_counts = sns.countplot(data = train_df, x = 'product_type', hue = 'buy')
product_type_counts.set(xlabel = 'Product Type', ylabel = 'Count', title = "Sample-Taker to Purchaser Based on Product Type")
product_type_counts.legend(title = "Purchased")
    
product_type_counts.figure.savefig(os.path.join(file_path, 'product_type_counts.png'))

# %%
free_shipping_counts = plt.figure(figsize = (10, 6))
free_shipping_counts = sns.countplot(data = train_df, x = 'free_shipping', hue = 'buy')
free_shipping_counts.set(xlabel = 'Free Shipping', ylabel = 'Count', title = 'Sample-Taker to Purchaser Based on Free Shipping')
free_shipping_counts.legend(title = "Purchased")

free_shipping_counts.figure.savefig(os.path.join(file_path, 'free_shipping_counts.png'))

# %% [markdown]
# Testing the entire script

# %%
data_path = "../../data/processed/cleaned_df.csv"
file_path = r"C:\Users\tktre\MDS\DSCI_591_Capstone\MDS-Capstone-Project\model-2-classification\src\visualization\output"

# %%
def test_images_created():
    main("../../data/processed/cleaned_df.csv", "output")
    assert os.path.isfile('output/skin_type_counts.png'), "skin_type_counts plot wasn't created."
    assert os.path.isfile('output/product_type_counts.png'), "product_type_counts plot wasn't created."
    assert os.path.isfile('output/free_shipping_counts.png'), "free_shipping_counts plot wasn't created."

# %%
def main(data_path, file_path):

    df = pd.read_csv(data_path)

    # split data into train test to get train_df
    X = df.drop(columns='buy')
    y = df[['buy']]
    X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=123)

    train_df = pd.concat([X_train, y_train], axis = 1)

    # first plot
    skin_type_counts = plt.figure(figsize = (10, 6))
    skin_type_counts = sns.countplot(data = train_df, x = 'skin_type', hue = 'buy')
    skin_type_counts.set(xlabel = 'Skin Type', ylabel = 'Count', title = "Sample-Taker to Purchaser Based on Skin Type")
    skin_type_counts.legend(title = "Purchased")
    
    skin_type_counts.figure.savefig(os.path.join(file_path, 'skin_type_counts.png'))
    
    # second plot
    product_type_counts = plt.figure(figsize = (10, 6))
    product_type_counts = sns.countplot(data = train_df, x = 'product_type', hue = 'buy')
    product_type_counts.set(xlabel = 'Product Type', ylabel = 'Count', title = "Sample-Taker to Purchaser Based on Product Type")
    product_type_counts.legend(title = "Purchased")
    
    product_type_counts.figure.savefig(os.path.join(file_path, 'product_type_counts.png'))
    
    # third plot
    free_shipping_counts = plt.figure(figsize = (10, 6))
    free_shipping_counts = sns.countplot(data = train_df, x = 'free_shipping', hue = 'buy')
    free_shipping_counts.set(xlabel = 'Free Shipping', ylabel = 'Count', title = 'Sample-Taker to Purchaser Based on Free Shipping')
    free_shipping_counts.legend(title = "Purchased")

    free_shipping_counts.figure.savefig(os.path.join(file_path, 'free_shipping_counts.png'))

# %%
test_images_created()
